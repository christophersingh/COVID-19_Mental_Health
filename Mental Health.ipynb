# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.cdc.gov", None)

results = client.get("8pt5-q6wp", limit=3000)

# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)
df.to_csv('./mental_health.csv')
df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#                                               indicator              group  \
# 0                       Symptoms of Depressive Disorder  National Estimate
# 1                       Symptoms of Depressive Disorder             By Age
# 2                       Symptoms of Depressive Disorder             By Age
# 3                       Symptoms of Depressive Disorder             By Age
# 4                       Symptoms of Depressive Disorder             By Age
# ...                                                 ...                ...
# 2515  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2516  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2517  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2518  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# ...

# %%
New_York = df[df['state']=='New York']
New_York
# Out:
#                                               indicator     group     state  \
# 51                      Symptoms of Depressive Disorder  By State  New York
# 121                        Symptoms of Anxiety Disorder  By State  New York
# 191   Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 261                     Symptoms of Depressive Disorder  By State  New York
# 331                        Symptoms of Anxiety Disorder  By State  New York
# 401   Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 471                     Symptoms of Depressive Disorder  By State  New York
# 541                        Symptoms of Anxiety Disorder  By State  New York
# 611   Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 681                     Symptoms of Depressive Disorder  By State  New York
# 751                        Symptoms of Anxiety Disorder  By State  New York
# ...

# %%
#Entire city data

borough_covid_count = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/by-boro.csv?raw=true", index_col=0)
age = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/by-age.csv?raw=true",index_col=0)
poverty = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/by-poverty.csv?raw=true", index_col=0)
race = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/by-race.csv?raw=true", index_col=0)
sex = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/by-sex.csv?raw=true",index_col=0)
hospital_cases = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/case-hosp-death.csv?raw=true")
zip_code = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/data-by-modzcta.csv?raw=true", index_col=0)
covid_summary = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/summary.csv?raw=true")
rate_of_hospital_visit = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/syndromic_data.csv?raw=true", index_col=0)
hospital_visit_4weeks = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/syndromic_data_4week.csv?raw=true", index_col=0)
covid_tests = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/tests.csv?raw=true", index_col=0)

# %%
#Get data sorted by borough 

borough_age = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/boro/boroughs-by-age.csv?raw=true", index_col=0)
borough_race = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/boro/boroughs-by-race.csv?raw=true", index_col=0)
borough_sex = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/boro/boroughs-by-sex.csv?raw=true", index_col=0)
borough_covid_counts = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/boro/boroughs-case-hosp-death.csv?raw=true", index_col=0)

# %%
#Data on Covid antibodies

antibody_age = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/testing/antibody-by-age.csv?raw=true", index_col=0)
antibody_by_boro = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/testing/antibody-by-boro.csv?raw=true", index_col=0)
antibody_zip_code = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/testing/antibody-by-modzcta.csv?raw=true", index_col=0)
antibody_poverty = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/testing/antibody-by-poverty.csv?raw=true", index_col=0)
antibody_sex = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/testing/antibody-by-sex.csv?raw=true", index_col=0)
antibody_by_week = pd.read_csv("https://github.com/nychealth/coronavirus-data/blob/master/testing/antibody-by-week.csv?raw=true", index_col=0)

# %%
race
# Out:
#                         CASE_RATE_ADJ  HOSPITALIZED_RATE_ADJ  DEATH_RATE_ADJ  \
# RACE_GROUP
# Asian/Pacific-Islander         744.53                 267.93          111.81
# Black/African-American        1784.11                 719.07          248.21
# Hispanic/Latino               1867.71                 697.28          263.18
# White                         1138.58                 323.76          123.99
#
#                         CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# RACE_GROUP
# Asian/Pacific-Islander       10058                3632         1438
# Black/African-American       36588               15418         5336
# Hispanic/Latino              45367               16366         5878
# White                        35542               11626         4862

# %%
hospital_cases[hospital_cases['DATE_OF_INTEREST']=="08/29/2020"]
# Out:
#     DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT  \
# 182       08/29/2020         114                  22            3
#
#      CASE_COUNT_7DAY_AVG  INCOMPLETE
# 182                236.0         NaN

# %%
age
# Out:
#            CASE_RATE  HOSPITALIZED_RATE  DEATH_RATE  CASE_COUNT  \
# AGE_GROUP
# 0-17          444.14              36.54        0.69        7670
# 18-44        2623.92             279.55       21.90       88418
# 45-64        3994.26             927.60      208.12       82124
# 65-74        3932.24            1787.25      676.42       27491
# 75+          4725.44            2865.94     1707.39       25847
# Citywide     2762.75             682.20      227.39      232036
#
#            HOSPITALIZED_COUNT  DEATH_COUNT
# AGE_GROUP
# 0-17                      631           12
# 18-44                    9420          738
# 45-64                   19072         4279
# 65-74                   12495         4729
# 75+                     15676         9339
# Citywide                57296        19098

# %%
Age = age.drop(['Citywide'])
Age.describe()
# Out:
#          CASE_RATE  HOSPITALIZED_RATE   DEATH_RATE    CASE_COUNT  \
# count     5.000000           5.000000     5.000000      5.000000
# mean   3144.000000        1179.376000   522.904000  46310.000000
# std    1688.560338        1161.159015   715.782034  36474.871453
# min     444.140000          36.540000     0.690000   7670.000000
# 25%    2623.920000         279.550000    21.900000  25847.000000
# 50%    3932.240000         927.600000   208.120000  27491.000000
# 75%    3994.260000        1787.250000   676.420000  82124.000000
# max    4725.440000        2865.940000  1707.390000  88418.000000
#
#        HOSPITALIZED_COUNT  DEATH_COUNT
# count            5.000000     5.000000
# mean         11458.800000  3819.400000
# std           7039.482559  3724.778826
# min            631.000000    12.000000
# 25%           9420.000000   738.000000
# 50%          12495.000000  4279.000000
# 75%          15676.000000  4729.000000
# max          19072.000000  9339.000000

# %%
Age.to_csv('Age.csv')

# %%
race = df[df['group']=='By State']
#ny = gr[gr['subgroup']=='Florida']
race.to_csv('State.csv',index=False)
race
# Out:
#                                               indicator     group  \
# 19                      Symptoms of Depressive Disorder  By State
# 20                      Symptoms of Depressive Disorder  By State
# 21                      Symptoms of Depressive Disorder  By State
# 22                      Symptoms of Depressive Disorder  By State
# 23                      Symptoms of Depressive Disorder  By State
# ...                                                 ...       ...
# 2515  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 2516  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 2517  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 2518  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 2519  Symptoms of Anxiety Disorder or Depressive Dis...  By State
#
#               state       subgroup week         week_label value lowci highci  \
# 19          Alabama        Alabama    1     Apr 23 - May 5  18.6  14.6   23.1
# ...

# %%
df['group'].unique()
# Out:
# array(['National Estimate', 'By Age', 'By Gender',
#        'By Race/Hispanic ethnicity', 'By Education', 'By State'],
#       dtype=object)
